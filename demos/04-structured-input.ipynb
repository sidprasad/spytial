# %% [markdown]
# # Building Dataclasses Visually with sPyTial

# %%
import sys
from pathlib import Path

# Add the parent directory to the Python path
sys.path.append(str(Path().resolve().parent))

from dataclasses import dataclass
from typing import Optional
from spytial import *

# %% [markdown]
# ## Example 1: Simple Binary Tree
#
# Let's start with a classic example: a binary tree node.
#
# We'll define a `TreeNode` dataclass with:
# - A `value` field (integer)
# - `left` and `right` child references (optional TreeNodes)
#
# Then we'll use `edit_html()` to create an instance visually.

# %%
@dataclass
@orientation(selector="{x, y : TreeNode | x.left = y}", directions=["below", "left"])
class TreeNode:
    value: int = 0
    left: Optional['TreeNode'] = None
    right: Optional['TreeNode'] = None

# %%
t = TreeNode(left=None, right=None, value=17)
edit_html(t)

# %%
# Example of what you might paste:
# my_tree = TreeNode(
#     value=42,
#     left=TreeNode(value=21, left=None, right=None),
#     right=TreeNode(value=84, left=None, right=None)
# )

# Paste your exported code here:

# %% [markdown]
# ## Example 2: Person with Address
#
# Let's try a more practical example: a Person dataclass with a nested Address.
#
# This demonstrates:
# - Multiple dataclass types in one builder
# - Nested object references
# - Different field types (strings, integers, optional references)

# %%
@dataclass
@attribute(field="street")
class Address:
    street: str = ""
    city: str = ""
    zip_code: str = ""

@dataclass
class Person:
    name: str = ""
    age: int = 0
    address: Optional[Address] = None

# %%
# Start with an empty Person
edit_html(Person())

# %% [markdown]
# **Steps to build a Person with Address:**
# 1. Edit the Person's `name` and `age` fields by clicking on them
# 2. Create an Address node (using "Add Node" and selecting Address type if available, or by connecting to the address field)
# 3. Edit the Address fields (`street`, `city`, `zip_code`)
# 4. Connect the Person's `address` field to the Address node
# 5. Export and paste the code below

# %%
# Paste your Person instance here:

# %% [markdown]
# ## Example 3: The live `Editor` widget
#
# The examples above use the **HTML path** (`edit_html()`), which renders
# standalone HTML in an iframe or browser tab. This works everywhere, including
# pyodide.
#
# For a richer experience in Jupyter, use the **widget path** — `edit()`, which
# returns an `Editor`. This is an `anywidget`-based widget with live two-way
# sync — edits in the visual editor are reflected back in Python immediately.
#
# Key differences:
# - **Live sync**: access the current state at any time via `.value`
# - **Change callbacks**: register listeners with `.on_change()`
# - **Context manager**: use `with` blocks for scoped editing sessions
#
# > Requires `anywidget` and `traitlets` (`pip install anywidget`).

# %%
# Create a widget-based editor using the same TreeNode from Example 1
builder = edit(TreeNode(value=10))
builder

# %%
# After editing visually, read back the current state as a Python object
builder.value

# %% [markdown]
# ### Using change callbacks
#
# You can register a callback that fires every time the user makes an edit in the widget:

# %%
person_builder = edit(Person(name="Alice", age=30))
person_builder.on_change(lambda person: print(f"Updated: {person}"))
person_builder
